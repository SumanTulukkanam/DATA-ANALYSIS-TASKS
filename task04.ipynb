# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime

# %%
data=pd.read_csv("C:\\Users\\suman\\Downloads\\USvideos.csv.crdownload")
data.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags      views     likes  \
# 0                                    SHANtell martin   748374.0   57527.0
# 1  last week tonight trump presidency|"last week ...  2418783.0   97185.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434.0  146033.0
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168.0   10172.0
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731.0  132235.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0    2966.0        15954.0  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1    6146.0        12703.0  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2    5339.0         8181.0  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3     666.0         2146.0  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4    1989.0        17518.0  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             False            False                  False
# 1             False            False                  False
# 2             False            False                  False
# 3             False            False                  False
# 4             False            False                  False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %%
data.shape
# Out:
# (21549, 16)

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (21549, 16)

# %%
data.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  21549.000000  2.154800e+04  2.154800e+04  2.154800e+04   2.154800e+04
# mean      20.010952  1.279972e+06  4.434590e+04  2.900272e+03   5.721782e+03
# std        7.610102  4.240696e+06  1.456694e+05  3.704731e+04   3.334330e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  1.048780e+05  2.083750e+03  9.600000e+01   3.020000e+02
# 50%       24.000000  3.353130e+05  9.211000e+03  3.390000e+02   1.058000e+03
# 75%       25.000000  1.032362e+06  3.001175e+04  1.152250e+03   3.442250e+03
# max       43.000000  1.493761e+08  3.093544e+06  1.674420e+06   1.361580e+06

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21549 entries, 0 to 21548
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                21549 non-null  object
#  1   trending_date           21549 non-null  object
#  2   title                   21549 non-null  object
#  3   channel_title           21549 non-null  object
#  4   category_id             21549 non-null  int64
#  5   publish_time            21549 non-null  object
#  6   tags                    21549 non-null  object
#  7   views                   21548 non-null  float64
#  8   likes                   21548 non-null  float64
#  9   dislikes                21548 non-null  float64
#  10  comment_count           21548 non-null  float64
#  11  thumbnail_link          21548 non-null  object
#  12  comments_disabled       21548 non-null  object
#  13  ratings_disabled        21548 non-null  object
#  14  video_error_or_removed  21548 non-null  object
#  15  description             21133 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 2.6+ MB

# %%
data.isnull().sum()
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       1
# likes                       1
# dislikes                    1
# comment_count               1
# thumbnail_link              1
# comments_disabled           1
# ratings_disabled            1
# video_error_or_removed      1
# description               416
# dtype: int64

# %%
columns_to_remove= ['thumbnail_link','description']
data=data.drop(columns=columns_to_remove)
data.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags      views     likes  \
# 0                                    SHANtell martin   748374.0   57527.0
# 1  last week tonight trump presidency|"last week ...  2418783.0   97185.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434.0  146033.0
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168.0   10172.0
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731.0  132235.0
#
#    dislikes  comment_count comments_disabled ratings_disabled  \
# 0    2966.0        15954.0             False            False
# 1    6146.0        12703.0             False            False
# 2    5339.0         8181.0             False            False
# 3     666.0         2146.0             False            False
# 4    1989.0        17518.0             False            False
#
#   video_error_or_removed
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %%
data.isnull().sum()
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     1
# likes                     1
# dislikes                  1
# comment_count             1
# comments_disabled         1
# ratings_disabled          1
# video_error_or_removed    1
# dtype: int64

# %%
from datetime import datetime

# %%
import datetime

# %%
data['trending_date']= data['trending_date'].apply(lambda x: datetime.datetime.strptime(x,'%y.%d.%m'))
data.head(3)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
#
#                                                title    channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE     CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...  LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...     Rudy Mancuso
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
#
#                                                 tags      views     likes  \
# 0                                    SHANtell martin   748374.0   57527.0
# 1  last week tonight trump presidency|"last week ...  2418783.0   97185.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434.0  146033.0
#
#    dislikes  comment_count comments_disabled ratings_disabled  \
# 0    2966.0        15954.0             False            False
# 1    6146.0        12703.0             False            False
# 2    5339.0         8181.0             False            False
#
#   video_error_or_removed
# 0                  False
# 1                  False
# 2                  False

# %%
data['publish_time']= pd.to_datetime(data['publish_time'])
data.head(4)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
#
#    category_id              publish_time  \
# 0           22 2017-11-13 17:13:01+00:00
# 1           24 2017-11-13 07:30:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-13 11:00:04+00:00
#
#                                                 tags      views     likes  \
# 0                                    SHANtell martin   748374.0   57527.0
# 1  last week tonight trump presidency|"last week ...  2418783.0   97185.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434.0  146033.0
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168.0   10172.0
#
#    dislikes  comment_count comments_disabled ratings_disabled  \
# 0    2966.0        15954.0             False            False
# 1    6146.0        12703.0             False            False
# 2    5339.0         8181.0             False            False
# 3     666.0         2146.0             False            False
#
#   video_error_or_removed
# 0                  False
# 1                  False
# 2                  False
# 3                  False

# %%
data['publish_month']= data['publish_time'].dt.month
data['publish_day']=data['publish_time'].dt.day
data['publish_hour']=data['publish_time'].dt.hour
data.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22 2017-11-13 17:13:01+00:00
# 1           24 2017-11-13 07:30:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-13 11:00:04+00:00
# 4           24 2017-11-12 18:01:41+00:00
#
#                                                 tags      views     likes  \
# 0                                    SHANtell martin   748374.0   57527.0
# 1  last week tonight trump presidency|"last week ...  2418783.0   97185.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434.0  146033.0
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168.0   10172.0
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731.0  132235.0
#
#    dislikes  comment_count comments_disabled ratings_disabled  \
# 0    2966.0        15954.0             False            False
# 1    6146.0        12703.0             False            False
# 2    5339.0         8181.0             False            False
# 3     666.0         2146.0             False            False
# 4    1989.0        17518.0             False            False
#
#   video_error_or_removed  publish_month  publish_day  publish_hour
# 0                  False             11           13            17
# 1                  False             11           13             7
# 2                  False             11           12            19
# 3                  False             11           13            11
# 4                  False             11           12            18

# %%
print(sorted (data['category_id'].unique()))
# Out:
# [1, 2, 10, 15, 17, 19, 20, 22, 23, 24, 25, 26, 27, 28, 29, 43]

# %%
data['category_name']= np.nan
data.loc[(data["category_id"] == 1), "category_name"]  = "Film and Animation"
data.loc[(data["category_id"] == 2), "category_name"]  = "Autos adn vehicles"
data.loc[(data["category_id"] == 10), "category_name"] = "Music"
data.loc[(data["category_id"] == 15), "category_name"] = "Pets and Animals"
data.loc[(data["category_id"] == 17), "category_name"] =  "Sports"
data.loc[(data["category_id"] == 19), "category_name"] = "Travel and Events"
data.loc[(data["category_id"] == 20), "category_name"] = "Gaming"
data.loc[(data["category_id"] == 22), "category_name"] = "People ans Blogs"
data.loc[(data["category_id"] == 23), "category_name"] = "Comedy"
data.loc[(data["category_id"] == 24), "category_name"] = "Entertainment"
data.loc[(data["category_id"] == 25), "category_name"] = "News and Politicians"
data.loc[(data["category_id"] == 26), "category_name"] = "How to and style"
data.loc[(data["category_id"] == 27), "category_name"] = "Education"
data.loc[(data["category_id"] == 28), "category_name"] = "Science and Technology"
data.loc[(data["category_id"] == 29), "category_name"] = "Non Profits and Activism"
data.loc[(data["category_id"] == 30), "category_name"] = "Movies"
data.loc[(data["category_id"] == 43), "category_name"] = "Shows"

data.head()
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_3008\232125080.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Film and Animation' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[(data["category_id"] == 1), "category_name"]  = "Film and Animation"
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22 2017-11-13 17:13:01+00:00
# 1           24 2017-11-13 07:30:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-13 11:00:04+00:00
# 4           24 2017-11-12 18:01:41+00:00
#
#                                                 tags      views     likes  \
# 0                                    SHANtell martin   748374.0   57527.0
# 1  last week tonight trump presidency|"last week ...  2418783.0   97185.0
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434.0  146033.0
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168.0   10172.0
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731.0  132235.0
#
#    dislikes  comment_count comments_disabled ratings_disabled  \
# 0    2966.0        15954.0             False            False
# 1    6146.0        12703.0             False            False
# 2    5339.0         8181.0             False            False
# 3     666.0         2146.0             False            False
# 4    1989.0        17518.0             False            False
#
#   video_error_or_removed  publish_month  publish_day  publish_hour  \
# 0                  False             11           13            17
# 1                  False             11           13             7
# 2                  False             11           12            19
# 3                  False             11           13            11
# 4                  False             11           12            18
#
#       category_name
# 0  People ans Blogs
# 1     Entertainment
# 2            Comedy
# 3     Entertainment
# 4     Entertainment

# %%
data['year']= data['publish_time'].dt.year
yearly_counts= data.groupby('year')['video_id'].count()

#Creating a bar plot
yearly_counts.plot(kind='bar', xlabel="Year", ylabel= "Total Publish Count",title="Total Publish Video Per Year")
plt.xticks(rotation=45)
plt.show()

# %%
#Group by year and sum the views of each year
yearly_views= data.groupby("year")["views"].sum()

#Creating a bar plot
yearly_views.plot(kind='bar', xlabel="Year", ylabel= "Total Views",title="Total Views Per Year")
plt.xticks(rotation=45)
plt.show()

# %%
#Group the data by "category name " and find the sum of the views in each
category_views= data.groupby("category_name")["views"].sum().reset_index()

#Sort the videos by views in descending order
top_categories= category_views.sort_values(by="views", ascending=False).head(5)


#Creating a bar plot to visualize the top 5 categroies
plt.bar(top_categories["category_name"],top_categories["views"])
plt.xlabel("Category Name")
plt.ylabel("Views")
plt.title("Top 5 Categories by Views")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6)) # Now you can call functions from the plt module
sns.countplot(x="category_name", data=data, order=data["category_name"].value_counts().index)
plt.title("Video count by category")
plt.xticks(rotation=90)
plt.show()

# %%
# Count the number of videos published per hour
videos_per_hour = data["publish_hour"].value_counts().sort_index()

# Plotting the number of videos published per hour
plt.figure(figsize=(12, 6))
sns.barplot(x=videos_per_hour.index, y=videos_per_hour.values, palette="rocket")
plt.title("Number of Videos Published per Hour")
plt.xlabel("Hour")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_3008\61496993.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=videos_per_hour.index, y=videos_per_hour.values, palette="rocket")

# %%
data["publish_time"]=pd.to_datetime(data["publish_time"])
data["publish_date"]=data["publish_time"].dt.date
video_count_by_date=data.groupby("publish_date")["video_id"].size()



plt.figure(figsize=(12,6))
sns.lineplot(data=video_count_by_date)
plt.title("Videos published Over Time")
plt.xlabel("Publish Date")
plt.ylabel("Number of Videos")
plt.show()

# %%
sns.scatterplot(data=data, x="views", y="likes")
plt.title("Views vs Likes")
plt.xlabel("Views")
plt.ylabel("Likes")
plt.show()

# %%
sns.scatterplot(data=data, x="views", y="dislikes")
plt.title("Views vs Dislikes")
plt.xlabel("Views")
plt.ylabel("Dislikes")
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.subplots_adjust(wspace=0.2, hspace=0.4, top=0.9)
plt.subplot(2,2,1)

g= sns.countplot(x="comments_disabled", data=data)
g.set_title("Comment Disabled", fontsize=16)
plt.subplot(2,2,2)

g1=sns.countplot(x="ratings_disabled", data=data)
g1.set_title("Ratings Disabled", fontsize=16)

plt.subplot(2,2,3)

g2=sns.countplot(x="video_error_or_removed", data=data)
g2.set_title("Video Error or Removed", fontsize=16)
plt.show()

# %%
corr_matrix=data["views"].corr(data["likes"])
corr_matrix
# Out:
# 0.8174841476839203
